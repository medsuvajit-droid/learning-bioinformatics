# %% [markdown]
# <a href="https://colab.research.google.com/github/medsuvajit-droid/learning-bioinformatics/blob/main/Python_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a Python program that asks the user for their name and age, then prints a personalized greeting that tells them how many years they have until they turn 100

# %%
print("Enter your name:")
# Out:
# Enter your name:

# %%
name = input()
# Out:
# Suvajit Chakraborty

# %%
print("Enter your age:")
# Out:
# Enter your age:

# %%
age = input()
# Out:
# 20

# %%
years = 100 - int(age)

# %%
print("Name:", (name))
# Out:
# Name: Suvajit Chakraborty

# %%
print("Age:", (age))
# Out:
# Age: 20

# %%
print("Years before you turn 100 years:", (years) ,"years")
# Out:
# Years before you turn 100 years: 80 years
